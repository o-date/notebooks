# %%
Patrinos_Exercise3b
# Out:
# Error in eval(expr, envir, enclos): object 'Patrinos_Exercise3b' not found
# Traceback:

# %%
install.packages("devtools") devtools::install_github("sfsheath/cawd") install.packages("sp")
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:30: unexpected symbol
# 1: install.packages("devtools") devtools
#                                  ^
# Traceback:

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
devtools::install_github("sfsheath/cawd")

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
devtools::install_github("sfsheath/cawd")
# Out:
# ...
# from URL https://api.github.com/repos/sfsheath/cawd/zipball/master
# Installing cawd
# '/usr/lib/R/bin/R' --no-site-file --no-environ --no-save --no-restore --quiet  \
#   CMD INSTALL '/tmp/RtmpPwOnLG/devtools9478efe703/sfsheath-cawd-928f175'  \
#   --library='/srv/rlibs' --install-tests

# %%
install.packages("sp")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library("sp") library("cawd") par(mai=c(0,0,0,0)) plot(awmc.roman.empire.200.sp)
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:15: unexpected symbol
# 1: library("sp") library
#                   ^
# Traceback:

# %%
library("cawd")

# %%
par(mai=c(0,0,0,0))

# %%
plot(awmc.roman.empire.200.sp)
# Out:
# Loading required package: sp
# Error in as.double(y): cannot coerce type 'S4' to vector of type 'double'
# Traceback:
#
# 1. plot(awmc.roman.empire.200.sp)
# 2. plot.default(awmc.roman.empire.200.sp)
# 3. xy.coords(x, y, xlabel, ylabel, log)

# %%
library("sp")

# %%
plot(awmc.roman.empire.200.sp)
# Out:
# plot without title

# %%
data()

# %%
plot(awmc.roman.territory.60bc.sp)
# Out:
# plot without title

# %%
plot(awmc.roman.senatorial.sp)
# Out:
# plot without title

# %% [markdown]
# Roman Senatorial
